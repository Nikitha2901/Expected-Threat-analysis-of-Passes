# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from mplsoccer import Pitch
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.metrics import accuracy_score, roc_auc_score,log_loss,brier_score_loss
from sklearn.metrics import roc_curve, auc
# Out:
# /tmp/ipykernel_186259/3028590550.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was too old on your system - pyarrow 10.0.1 is the current minimum supported version as of this release.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
features_all = pd.read_csv("../data/features_2022_2023_final.csv")

# %%
features_all.columns
# Out:
# Index(['id', 'match_id', 'team_id', 'possession_team_id', 'player_id',
#        'passer_name', 'pass_recipient_id', 'receiver_name', 'team_name',
#        'start_x', 'start_y', 'end_x', 'end_y', 'passer_x', 'passer_y',
#        'start_distance_to_goal', 'end_distance_to_goal', 'pass_length',
#        'pass_angle', 'start_angle_to_goal', 'end_angle_to_goal',
#        'start_distance_to_sideline', 'end_distance_to_sideline',
#        'forward pass', 'backward pass', 'lateral pass', 'teammates_behind',
#        'teammates_beyond', 'opponents_beyond', 'opponents_behind',
#        'opponents_between', 'packing', 'pressure_on_passer',
#        'average_speed_of_teammates', 'average_speed_of_opponents',
#        'opponents_nearby', 'pressure level passer', 'teammates_nearby',
#        'possession_xg', 'possession_goal', 'possession_xG_target', 'season',
#        'speed_difference', 'h1', 'h2', 'h3', 'h4'],
#       dtype='object')

# %%
features_all = features_all [['id','start_distance_to_goal', 'end_distance_to_goal', 'pass_length',
       'pass_angle', 'start_angle_to_goal', 'end_angle_to_goal',
       'start_distance_to_sideline', 'end_distance_to_sideline','teammates_behind',
       'teammates_beyond', 'opponents_beyond', 'opponents_behind',
       'opponents_between', 'packing', 'pressure_on_passer',
       'average_speed_of_teammates', 'average_speed_of_opponents',
       'opponents_nearby','teammates_nearby','possession_xG_target']]

# %%
features_train = features_all[['possession_xG_target', 'start_distance_to_goal',
       'end_distance_to_goal', 'pass_length', 'pass_angle','start_angle_to_goal','end_angle_to_goal',
       'start_distance_to_sideline', 'end_distance_to_sideline','teammates_behind',
       'teammates_beyond','opponents_beyond','opponents_behind','opponents_between','packing','pressure_on_passer','average_speed_of_teammates',
       'average_speed_of_opponents', 'opponents_nearby', 'teammates_nearby']]

# %% [markdown]
# ### pressure based model

# %%
X_1 = features_train[['packing','pressure_on_passer','teammates_nearby','opponents_nearby']]

Y_1 = features_train[['possession_xG_target']]

X_train_1,X_test_1,Y_train_1,Y_test_1 = train_test_split(X_1,Y_1,test_size=0.25,random_state=50)

logit_formula_1 = "possession_xG_target ~ packing + pressure_on_passer + teammates_nearby + opponents_nearby"

train_data_1 = X_train_1.copy()
train_data_1['possession_xG_target'] = Y_train_1

model_roc_1 = smf.logit(logit_formula_1, data=train_data_1).fit(method='bfgs', maxiter=200)

model_roc_1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.373694
#          Iterations: 29
#          Function evaluations: 31
#          Gradient evaluations: 31
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             Logit Regression Results
# ================================================================================
# Dep. Variable:     possession_xG_target   No. Observations:                55565
# Model:                            Logit   Df Residuals:                    55560
# Method:                             MLE   Df Model:                            4
# Date:                  Sat, 24 May 2025   Pseudo R-squ.:                0.003091
# Time:                          06:31:37   Log-Likelihood:                -20764.
# converged:                         True   LL-Null:                       -20829.
# Covariance Type:              nonrobust   LLR p-value:                 7.111e-27
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -2.1967      0.026    -83.863      0.000      -2.248      -2.145
# packing                0.0468      0.008      5.775      0.000       0.031       0.063
# pressure_on_passer     0.0915      0.052      1.762      0.078      -0.010       0.193
# teammates_nearby      -0.0370      0.027     -1.367      0.172      -0.090       0.016
# opponents_nearby       0.0863      0.024      3.671      0.000       0.040       0.132
# ======================================================================================
# """

# %%
test_data_1 = X_test_1.copy()
test_data_1['possession_xG_target'] = Y_test_1
y_pred_prob_1 = model_roc_1.predict(test_data_1)
fpr, tpr, thresholds = roc_curve(Y_test_1,y_pred_prob_1)
roc_auc_1 = auc(fpr, tpr)
roc_auc_1 = roc_auc_score(Y_test_1, y_pred_prob_1)
brier_1  = brier_score_loss(Y_test_1, y_pred_prob_1)
logloss_1 = log_loss(Y_test_1, y_pred_prob_1)
print(f"ROC AUC :      {roc_auc_1:.4f}")
print(f"Logloss:{logloss_1:.4f}")
print(f"Brier Score:  {brier_1:.4f}")
# Out:
# ROC AUC :      0.5428
# Logloss:0.3782
# Brier Score:  0.1101

# %%
plt.figure(figsize=(7,5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc_1:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal reference line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Pressue based model Logistic Regression')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### speed based model

# %%
X_2 = features_train[['average_speed_of_teammates',
       'average_speed_of_opponents']]

Y_2 = features_train[['possession_xG_target']]

X_train_2,X_test_2,Y_train_2,Y_test_2 = train_test_split(X_2,Y_2,test_size=0.25,random_state=50)

logit_formula_2 = "possession_xG_target ~ average_speed_of_teammates + average_speed_of_opponents"

train_data_2 = X_train_2.copy()
train_data_2['possession_xG_target'] = Y_train_2

model_roc_2 = smf.logit(logit_formula_2, data=train_data_2).fit(method='bfgs', maxiter=200)

model_roc_2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.370745
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             Logit Regression Results
# ================================================================================
# Dep. Variable:     possession_xG_target   No. Observations:                55565
# Model:                            Logit   Df Residuals:                    55562
# Method:                             MLE   Df Model:                            2
# Date:                  Sat, 24 May 2025   Pseudo R-squ.:                 0.01096
# Time:                          06:31:46   Log-Likelihood:                -20600.
# converged:                         True   LL-Null:                       -20829.
# Covariance Type:              nonrobust   LLR p-value:                7.287e-100
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -2.6607      0.036    -73.876      0.000      -2.731      -2.590
# average_speed_of_teammates     0.1567      0.033      4.819      0.000       0.093       0.220
# average_speed_of_opponents     0.1277      0.030      4.232      0.000       0.069       0.187
# ==============================================================================================
# """

# %%
test_data_2 = X_test_2.copy()
test_data_2['possession_xG_target'] = Y_test_2
y_pred_prob_2 = model_roc_2.predict(test_data_2)
fpr, tpr, thresholds = roc_curve(Y_test_2,y_pred_prob_2)
roc_auc_2 = auc(fpr, tpr)
brier_2  = brier_score_loss(Y_test_2, y_pred_prob_2)
logloss_2 = log_loss(Y_test_2, y_pred_prob_2)
print(f"ROC AUC:      {roc_auc_2:.4f}")
print(f"Logloss:{logloss_2:.4f}")
print(f"Brier Score:  {brier_2:.4f}")
# Out:
# ROC AUC:      0.5685
# Logloss:0.3752
# Brier Score:  0.1094

# %%
plt.figure(figsize=(7,5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc_2:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal reference line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Speed based model Logistic Regression')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### position based features

# %%
X_3 = features_train[['teammates_behind',
       'teammates_beyond', 'opponents_beyond', 'opponents_behind',
       'opponents_between']]

Y_3 = features_train[['possession_xG_target']]

X_train_3,X_test_3,Y_train_3,Y_test_3 = train_test_split(X_3,Y_3,test_size=0.25,random_state=50)

logit_formula_3 = "possession_xG_target ~ teammates_behind + teammates_beyond + opponents_beyond + opponents_behind + opponents_between"

train_data_3 = X_train_3.copy()
train_data_3['possession_xG_target'] = Y_train_3

model_roc_3 = smf.logit(logit_formula_3, data=train_data_3).fit(method='bfgs', maxiter=200)

model_roc_3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.367221
#          Iterations: 35
#          Function evaluations: 39
#          Gradient evaluations: 39
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             Logit Regression Results
# ================================================================================
# Dep. Variable:     possession_xG_target   No. Observations:                55565
# Model:                            Logit   Df Residuals:                    55559
# Method:                             MLE   Df Model:                            5
# Date:                  Sat, 24 May 2025   Pseudo R-squ.:                 0.02036
# Time:                          06:31:58   Log-Likelihood:                -20405.
# converged:                         True   LL-Null:                       -20829.
# Covariance Type:              nonrobust   LLR p-value:                4.532e-181
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             1.7604      0.536      3.284      0.001       0.710       2.811
# teammates_behind      0.0555      0.027      2.083      0.037       0.003       0.108
# teammates_beyond     -0.0214      0.027     -0.786      0.432      -0.075       0.032
# opponents_beyond     -0.4132      0.041     -9.959      0.000      -0.495      -0.332
# opponents_behind     -0.3198      0.041     -7.707      0.000      -0.401      -0.238
# opponents_between     0.0480      0.006      8.703      0.000       0.037       0.059
# =====================================================================================
# """

# %%
from sklearn.metrics import roc_curve, auc

test_data_3 = X_test_3.copy()
test_data_3['possession_xG_target'] = Y_test_3
y_pred_prob_3 = model_roc_3.predict(test_data_3)
fpr, tpr, thresholds = roc_curve(Y_test_3,y_pred_prob_3)
roc_auc_3 = auc(fpr, tpr)
brier_3  = brier_score_loss(Y_test_3, y_pred_prob_3)
logloss_3 = log_loss(Y_test_3, y_pred_prob_3)
print(f"ROC AUC:      {roc_auc_3:.4f}")
print(f"Logloss:{logloss_3:.4f}")
print(f"Brier Score:  {brier_3:.4f}")
# Out:
# ROC AUC:      0.6136
# Logloss:0.3701
# Brier Score:  0.1081

# %%
plt.figure(figsize=(7,5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc_3:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal reference line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Position based model Logistic Regression')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### event based model

# %%
X_4 = features_all[['start_distance_to_goal',
       'end_distance_to_goal', 'pass_length', 'pass_angle','start_angle_to_goal','end_angle_to_goal',
       'start_distance_to_sideline', 'end_distance_to_sideline']]
Y_4 = features_all[["possession_xG_target"]]

X_train_4,X_test_4,Y_train_4,Y_test_4 = train_test_split(X_4,Y_4,test_size=0.25,random_state=50)

logit_formula_4 = "possession_xG_target ~ start_distance_to_goal + end_distance_to_goal + pass_length + pass_angle + start_angle_to_goal + end_angle_to_goal + start_distance_to_sideline + end_distance_to_sideline"

train_data_4 = X_train_4.copy()
train_data_4['possession_xG_target'] = Y_train_4

model_roc_4 = smf.logit(logit_formula_4, data=train_data_4).fit(method='bfgs', maxiter=200)
model_roc_4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.358550
#          Iterations: 42
#          Function evaluations: 49
#          Gradient evaluations: 49
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             Logit Regression Results
# ================================================================================
# Dep. Variable:     possession_xG_target   No. Observations:                55565
# Model:                            Logit   Df Residuals:                    55556
# Method:                             MLE   Df Model:                            8
# Date:                  Sat, 24 May 2025   Pseudo R-squ.:                 0.04349
# Time:                          06:32:09   Log-Likelihood:                -19923.
# converged:                         True   LL-Null:                       -20829.
# Covariance Type:              nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      1.1787      0.242      4.863      0.000       0.704       1.654
# start_distance_to_goal        -0.0253      0.002    -12.647      0.000      -0.029      -0.021
# end_distance_to_goal           0.0081      0.008      1.023      0.306      -0.007       0.024
# pass_length                   -0.0027      0.001     -2.135      0.033      -0.005      -0.000
# pass_angle                     0.0007      0.000      6.052      0.000       0.000       0.001
# start_angle_to_goal            0.0372      0.012      3.052      0.002       0.013       0.061
# end_angle_to_goal             -0.7725      0.120     -6.449      0.000      -1.007      -0.538
# start_distance_to_sideline     0.0106      0.002      5.603      0.000       0.007       0.014
# end_distance_to_sideline       0.0401      0.008      5.107      0.000       0.025       0.056
# ==============================================================================================
# """

# %%
from sklearn.metrics import roc_curve, auc


test_data_4 = X_test_4.copy()
test_data_4['possession_xG_target'] = Y_test_4
y_pred_prob_4 = model_roc_4.predict(test_data_4)
fpr, tpr, thresholds = roc_curve(Y_test_4,y_pred_prob_4)
roc_auc_4 = auc(fpr, tpr)
brier_4  = brier_score_loss(Y_test_4, y_pred_prob_4)
logloss_4 = log_loss(Y_test_4, y_pred_prob_4)
print(f"ROC AUC:      {roc_auc_4:.4f}")
print(f"Logloss:{logloss_4:.4f}")
print(f"Brier Score:  {brier_4:.4f}")
# Out:
# ROC AUC:      0.6536
# Logloss:0.3623
# Brier Score:  0.1058

# %%
plt.figure(figsize=(7,5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc_4:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal reference line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Event based logistic regression')
plt.legend(loc="lower right")
plt.show()

# %%
import joblib
joblib.dump(model_roc_1, 'pressure_based_model.sav')
# Out:
# ['pressure_based_model.sav']

# %%
joblib.dump(model_roc_2,'speed_based_model.sav')
# Out:
# ['speed_based_model.sav']

# %%
joblib.dump(model_roc_3,'position_based_model.sav')
# Out:
# ['position_based_model.sav']

# %%
joblib.dump(model_roc_4,'event_based_model.sav')
# Out:
# ['event_based_model.sav']

# %%
pressure_model_params = model_roc_1.params

# %%
pressure_model_params.to_csv("pressure_model_params.csv",index=False)

# %%
speed_model_params = model_roc_2.params
speed_model_params.to_csv("speed_model_params.csv",index=False)

# %%
position_model_params = model_roc_3.params
position_model_params.to_csv("position_model_params.csv",index=False)

# %%
event_model_params = model_roc_4.params
event_model_params.to_csv("event_model_params.csv",index=False)

# %%
event_model_params
# Out:
# Intercept                     1.178742
# start_distance_to_goal       -0.025342
# end_distance_to_goal          0.008073
# pass_length                  -0.002677
# pass_angle                    0.000709
# start_angle_to_goal           0.037220
# end_angle_to_goal            -0.772534
# start_distance_to_sideline    0.010628
# end_distance_to_sideline      0.040132
# dtype: float64

# %% [markdown]
# ### neural network

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df_params_model_1 = pd.DataFrame(model_roc_1.params,columns=["value_model1_coeff"]).reset_index()
df_params_model_1.rename(columns={'index':'model1_coeff'},inplace = True)

df_params_model_2 = pd.DataFrame(model_roc_2.params,columns=["value_model2_coeff"]).reset_index()
df_params_model_2.rename(columns={'index':'model2_coeff'},inplace = True)

df_params_model_3 = pd.DataFrame(model_roc_3.params,columns=["value_model3_coeff"]).reset_index()
df_params_model_3.rename(columns={'index':'model3_coeff'},inplace = True)

df_params_model_4 = pd.DataFrame(model_roc_4.params,columns=["value_model4_coeff"]).reset_index()
df_params_model_4.rename(columns={'index':'model4_coeff'},inplace = True)

# %%
# Reset indices
X_1_reset = X_1.reset_index(drop=True)
X_2_reset = X_2.reset_index(drop=True)
X_3_reset = X_3.reset_index(drop=True)
X_4_reset = X_4.reset_index(drop=True)

# Identify and remove overlapping columns from X_2
overlap_cols_2 = X_1.columns.intersection(X_2.columns)
X_2_dedup = X_2_reset.drop(columns=overlap_cols_2)

# Combine X_1 and X_2_dedup
df_features = pd.concat([X_1_reset, X_2_dedup], axis=1)

# Identify and remove overlapping columns from X_3
overlap_cols_3 = df_features.columns.intersection(X_3.columns)
X_3_dedup = X_3_reset.drop(columns=overlap_cols_3)

df_features = pd.concat([df_features, X_3_dedup], axis=1)


overlap_cols_4 = df_features.columns.intersection(X_4.columns)
X_4_dedup = X_4_reset.drop(columns=overlap_cols_4)


df_features = pd.concat([df_features,X_4_dedup],axis=1)

# %%
df_params_model_1 = df_params_model_1[df_params_model_1["model1_coeff"] != "Intercept"]
df_params_model_2 = df_params_model_2[df_params_model_2["model2_coeff"] != "Intercept"]
df_params_model_3 = df_params_model_3[df_params_model_3["model3_coeff"] != "Intercept"]
df_params_model_4 = df_params_model_4[df_params_model_4["model4_coeff"] != "Intercept"]

# %%
beta1 = df_params_model_1.set_index('model1_coeff')['value_model1_coeff']
beta2 = df_params_model_2.set_index('model2_coeff')['value_model2_coeff']
beta3 = df_params_model_3.set_index('model3_coeff')['value_model3_coeff']
beta4 = df_params_model_4.set_index('model4_coeff')['value_model4_coeff']

# %%
model1_features = X_1.copy()
model2_features = X_2.copy()
model3_features = X_3.copy()
model4_features = X_4.copy()

# %%
df_features['z1'] = model1_features.mul(beta1,axis=1).sum(axis=1)
df_features['z2'] = model2_features.mul(beta2,axis=1).sum(axis=1)
df_features['z3'] = model3_features.mul(beta3,axis=1).sum(axis=1)
df_features['z4'] = model4_features.mul(beta4,axis=1).sum(axis=1)

# %%
df_features["pressure based"] = 1 / (1 + np.exp(-df_features['z1']))
df_features["speed based"] = 1 / (1 + np.exp(-df_features['z2']))
df_features["position based"] = 1 / (1 + np.exp(-df_features['z3']))
df_features["event based"] = 1 / (1 + np.exp(-df_features['z4']))

# %%
features_all.columns
# Out:
# Index(['id', 'start_distance_to_goal', 'end_distance_to_goal', 'pass_length',
#        'pass_angle', 'start_angle_to_goal', 'end_angle_to_goal',
#        'start_distance_to_sideline', 'end_distance_to_sideline',
#        'teammates_behind', 'teammates_beyond', 'opponents_beyond',
#        'opponents_behind', 'opponents_between', 'packing',
#        'pressure_on_passer', 'average_speed_of_teammates',
#        'average_speed_of_opponents', 'opponents_nearby', 'teammates_nearby',
#        'possession_xG_target'],
#       dtype='object')

# %%
df_features.columns
# Out:
# Index(['packing', 'pressure_on_passer', 'teammates_nearby', 'opponents_nearby',
#        'average_speed_of_teammates', 'average_speed_of_opponents',
#        'teammates_behind', 'teammates_beyond', 'opponents_beyond',
#        'opponents_behind', 'opponents_between', 'start_distance_to_goal',
#        'end_distance_to_goal', 'pass_length', 'pass_angle',
#        'start_angle_to_goal', 'end_angle_to_goal',
#        'start_distance_to_sideline', 'end_distance_to_sideline', 'z1', 'z2',
#        'z3', 'z4', 'pressure based', 'speed based', 'position based',
#        'event based'],
#       dtype='object')

# %%
df_features["possession_xG_target"] = features_all["possession_xG_target"]
df_features["id"] = features_all["id"]

# %%
df_features.columns
# Out:
# Index(['packing', 'pressure_on_passer', 'teammates_nearby', 'opponents_nearby',
#        'average_speed_of_teammates', 'average_speed_of_opponents',
#        'teammates_behind', 'teammates_beyond', 'opponents_beyond',
#        'opponents_behind', 'opponents_between', 'start_distance_to_goal',
#        'end_distance_to_goal', 'pass_length', 'pass_angle',
#        'start_angle_to_goal', 'end_angle_to_goal',
#        'start_distance_to_sideline', 'end_distance_to_sideline', 'z1', 'z2',
#        'z3', 'z4', 'pressure based', 'speed based', 'position based',
#        'event based', 'possession_xG_target', 'id'],
#       dtype='object')

# %%
df_features
# Out:
#        packing  pressure_on_passer  teammates_nearby  opponents_nearby  \
# 0            2            0.000000                 0                 0
# 1            1            0.777216                 0                 1
# 2            1            0.483192                 0                 1
# 3            1            0.193301                 0                 1
# 4            3            0.080622                 0                 1
# ...        ...                 ...               ...               ...
# 74082        3            0.550305                 0                 2
# 74083        3            0.018224                 1                 1
# 74084        3            0.453654                 1                 1
# 74085        2            1.157373                 2                 2
# 74086        2            0.000000                 0                 0
#
#        average_speed_of_teammates  average_speed_of_opponents  \
# 0                        2.548364                    3.055364
# 1                        2.347700                    2.346909
# 2                        3.192000                    2.942000
# 3                        2.076364                    2.067000
# 4                        1.566364                    1.748000
# ...                           ...                         ...
# 74082                    2.924000                    2.798182
# 74083                    3.270364                    2.900100
# 74084                    0.945455                    0.732000
# 74085                    1.761818                    2.840100
# 74086                    2.884455                    2.547182
#
#        teammates_behind  teammates_beyond  opponents_beyond  opponents_behind  \
# 0                     3                 7                10                 1
# 1                     4                 5                 8                 3
# 2                     2                 8                10                 1
# 3                     7                 3                 8                 3
# 4                     3                 7                10                 1
# ...                 ...               ...               ...               ...
# 74082                 8                 3                 5                 6
# 74083                 8                 3                 4                 6
# 74084                10                 1                 2                 8
# 74085                 5                 6                 4                 6
# 74086                 1                10                11                 0
#
#        ...        z1        z2        z3        z4  pressure based  \
# 0      ...  0.093606  0.789426 -4.003393 -3.968882        0.523384
# 1      ...  0.204154  0.667511 -3.862186 -3.426184        0.550862
# 2      ...  0.177265  0.875776 -4.464533 -3.850920        0.544200
# 3      ...  0.150754  0.589257 -3.604636 -2.966088        0.537617
# 4      ...  0.234055  0.468623 -4.339524 -4.049942        0.558248
# ...    ...       ...       ...       ...       ...             ...
# 74082  ...  0.363281  0.815425 -3.412899 -2.116559        0.589834
# 74083  ...  0.191357  0.882701 -2.999669 -3.872681        0.547694
# 74084  ...  0.231178  0.241596 -2.418764 -2.868414        0.557538
# 74085  ...  0.298012  0.638719 -3.230642 -2.446048        0.573957
# 74086  ...  0.093606  0.777174 -4.224213 -4.102256        0.523384
#
#        speed based  position based  event based  possession_xG_target  \
# 0         0.687708        0.017926     0.018544                     0
# 1         0.660946        0.020589     0.031487                     0
# 2         0.705946        0.011379     0.020818                     0
# 3         0.643195        0.026477     0.048982                     0
# 4         0.615058        0.012875     0.017125                     0
# ...            ...             ...          ...                   ...
# 74082     0.693264        0.031895     0.107498                     0
# 74083     0.707382        0.047441     0.020379                     0
# 74084     0.560107        0.081753     0.053737                     0
# 74085     0.654464        0.038029     0.079728                     0
# 74086     0.685071        0.014426     0.016266                     0
#
#                id
# 0      1256506933
# 1      1256508233
# 2      1256507062
# 3      1256507101
# 4      1256507134
# ...           ...
# 74082  1625749288
# 74083  1625749300
# 74084  1625749310
# 74085  1625748978
# 74086  1625748995
#
# [74087 rows x 29 columns]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, precision_score , log_loss , brier_score_loss
import numpy as np
import random

# -------------------------------
# Set seed for reproducibility
# -------------------------------
def set_seed(seed):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(70) 

#load data
X = df_features[['pressure based', 'speed based', 'position based',
       'event based']].values

y = df_features['possession_xG_target'].values

# Train and test split
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=50
)

# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_raw)
X_test_scaled  = scaler.transform(X_test_raw)

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
X_test_tensor  = torch.tensor(X_test_scaled, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
y_test_tensor  = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

#model setup
class SimplerNet(nn.Module):
    def __init__(self, input_dim):
        super(SimplerNet, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 16),
            nn.ReLU(),
            # nn.Dropout(0.2),  # optional
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.model(x)

model_1 = SimplerNet(input_dim=X_train_tensor.shape[1])

#training setup
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_1.parameters(), lr=0.008, weight_decay=1e-5)
n_epochs = 10000

#training loop
torch.set_grad_enabled(True)
for epoch in range(1, n_epochs+1):
    model_1.train()
    optimizer.zero_grad()

    outputs = model_1(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    # verify that loss requires grad
    assert loss.requires_grad, "Gradients are disabled on loss!"
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0 or epoch == 1:
        with torch.no_grad():
            train_probs = torch.sigmoid(outputs)
            train_preds = (train_probs >= 0.5).float()
            train_acc = (train_preds == y_train_tensor).float().mean().item()
        print(f"Epoch [{epoch}/{n_epochs}] - "
              f"Train Loss: {loss.item():.4f} | "
              f"Train Acc: {train_acc:.4f}")

# model evaluation

model_1.eval()
with torch.no_grad():
    test_logits = model_1(X_test_tensor)
    test_probs = torch.sigmoid(test_logits).numpy()
    test_preds = (test_probs >= 0.5).astype(int)

# Metrics
acc       = accuracy_score(y_test_tensor.numpy(), test_preds)
auc       = roc_auc_score(y_test_tensor.numpy(), test_probs)
f1        = f1_score(y_test_tensor.numpy(), test_preds)
precision = precision_score(y_test_tensor.numpy(), test_preds)
logloss    = log_loss(y_test_tensor.numpy(), test_probs)
brier      = brier_score_loss(y_test_tensor.numpy(), test_probs)

print("\n--- Test Set Evaluation ---")
print(f"AUC:       {auc:.4f}")
print(f"Log Loss:     {logloss:.4f}")
print(f"Brier Score:  {brier:.4f}")
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1 Score:  {f1:.4f}")
# Out:
# Epoch [1/10000] - Train Loss: 0.7036 | Train Acc: 0.4923
# Epoch [10/10000] - Train Loss: 0.5576 | Train Acc: 0.8760
# Epoch [20/10000] - Train Loss: 0.4506 | Train Acc: 0.8760
# Epoch [30/10000] - Train Loss: 0.3869 | Train Acc: 0.8760
# Epoch [40/10000] - Train Loss: 0.3658 | Train Acc: 0.8760
# Epoch [50/10000] - Train Loss: 0.3639 | Train Acc: 0.8760
# Epoch [60/10000] - Train Loss: 0.3626 | Train Acc: 0.8760
# Epoch [70/10000] - Train Loss: 0.3605 | Train Acc: 0.8760
# Epoch [80/10000] - Train Loss: 0.3591 | Train Acc: 0.8760
# Epoch [90/10000] - Train Loss: 0.3583 | Train Acc: 0.8760
# Epoch [100/10000] - Train Loss: 0.3573 | Train Acc: 0.8761
# Epoch [110/10000] - Train Loss: 0.3562 | Train Acc: 0.8768
# Epoch [120/10000] - Train Loss: 0.3551 | Train Acc: 0.8769
# Epoch [130/10000] - Train Loss: 0.3544 | Train Acc: 0.8767
# Epoch [140/10000] - Train Loss: 0.3539 | Train Acc: 0.8766
# Epoch [150/10000] - Train Loss: 0.3535 | Train Acc: 0.8767
# Epoch [160/10000] - Train Loss: 0.3532 | Train Acc: 0.8766
# Epoch [170/10000] - Train Loss: 0.3529 | Train Acc: 0.8765
# Epoch [180/10000] - Train Loss: 0.3526 | Train Acc: 0.8766
# Epoch [190/10000] - Train Loss: 0.3524 | Train Acc: 0.8768
# Epoch [200/10000] - Train Loss: 0.3522 | Train Acc: 0.8769
# Epoch [210/10000] - Train Loss: 0.3520 | Train Acc: 0.8768
# Epoch [220/10000] - Train Loss: 0.3519 | Train Acc: 0.8769
# Epoch [230/10000] - Train Loss: 0.3518 | Train Acc: 0.8769
# Epoch [240/10000] - Train Loss: 0.3516 | Train Acc: 0.8769
# Epoch [250/10000] - Train Loss: 0.3516 | Train Acc: 0.8768
# Epoch [260/10000] - Train Loss: 0.3515 | Train Acc: 0.8768
# Epoch [270/10000] - Train Loss: 0.3514 | Train Acc: 0.8769
# Epoch [280/10000] - Train Loss: 0.3514 | Train Acc: 0.8769
# Epoch [290/10000] - Train Loss: 0.3514 | Train Acc: 0.8769
# Epoch [300/10000] - Train Loss: 0.3513 | Train Acc: 0.8769
# Epoch [310/10000] - Train Loss: 0.3513 | Train Acc: 0.8769
# Epoch [320/10000] - Train Loss: 0.3513 | Train Acc: 0.8769
# Epoch [330/10000] - Train Loss: 0.3513 | Train Acc: 0.8769
# Epoch [340/10000] - Train Loss: 0.3513 | Train Acc: 0.8770
# Epoch [350/10000] - Train Loss: 0.3512 | Train Acc: 0.8770
# Epoch [360/10000] - Train Loss: 0.3512 | Train Acc: 0.8770
# Epoch [370/10000] - Train Loss: 0.3512 | Train Acc: 0.8770
# Epoch [380/10000] - Train Loss: 0.3512 | Train Acc: 0.8770
# Epoch [390/10000] - Train Loss: 0.3512 | Train Acc: 0.8770
# Epoch [400/10000] - Train Loss: 0.3512 | Train Acc: 0.8769
# Epoch [410/10000] - Train Loss: 0.3511 | Train Acc: 0.8769
# Epoch [420/10000] - Train Loss: 0.3511 | Train Acc: 0.8769
# Epoch [430/10000] - Train Loss: 0.3511 | Train Acc: 0.8769
# Epoch [440/10000] - Train Loss: 0.3511 | Train Acc: 0.8769
# Epoch [450/10000] - Train Loss: 0.3511 | Train Acc: 0.8769
# Epoch [460/10000] - Train Loss: 0.3511 | Train Acc: 0.8769
# Epoch [470/10000] - Train Loss: 0.3510 | Train Acc: 0.8770
# Epoch [480/10000] - Train Loss: 0.3510 | Train Acc: 0.8769
# Epoch [490/10000] - Train Loss: 0.3510 | Train Acc: 0.8769
# Epoch [500/10000] - Train Loss: 0.3510 | Train Acc: 0.8769
# Epoch [510/10000] - Train Loss: 0.3510 | Train Acc: 0.8770
# Epoch [520/10000] - Train Loss: 0.3510 | Train Acc: 0.8769
# Epoch [530/10000] - Train Loss: 0.3509 | Train Acc: 0.8769
# Epoch [540/10000] - Train Loss: 0.3509 | Train Acc: 0.8769
# Epoch [550/10000] - Train Loss: 0.3509 | Train Acc: 0.8770
# Epoch [560/10000] - Train Loss: 0.3509 | Train Acc: 0.8770
# Epoch [570/10000] - Train Loss: 0.3509 | Train Acc: 0.8770
# Epoch [580/10000] - Train Loss: 0.3509 | Train Acc: 0.8770
# Epoch [590/10000] - Train Loss: 0.3509 | Train Acc: 0.8770
# Epoch [600/10000] - Train Loss: 0.3508 | Train Acc: 0.8769
# Epoch [610/10000] - Train Loss: 0.3508 | Train Acc: 0.8769
# Epoch [620/10000] - Train Loss: 0.3508 | Train Acc: 0.8769
# Epoch [630/10000] - Train Loss: 0.3508 | Train Acc: 0.8769
# Epoch [640/10000] - Train Loss: 0.3508 | Train Acc: 0.8769
# Epoch [650/10000] - Train Loss: 0.3508 | Train Acc: 0.8769
# Epoch [660/10000] - Train Loss: 0.3508 | Train Acc: 0.8769
# Epoch [670/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [680/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [690/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [700/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [710/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [720/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [730/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [740/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [750/10000] - Train Loss: 0.3508 | Train Acc: 0.8771
# Epoch [760/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [770/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [780/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [790/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [800/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [810/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [820/10000] - Train Loss: 0.3508 | Train Acc: 0.8770
# Epoch [830/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [840/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [850/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [860/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [870/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [880/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [890/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [900/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [910/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [920/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [930/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [940/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [950/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [960/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [970/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [980/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [990/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [1000/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [1010/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [1020/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [1030/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [1040/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [1050/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [1060/10000] - Train Loss: 0.3507 | Train Acc: 0.8771
# Epoch [1070/10000] - Train Loss: 0.3507 | Train Acc: 0.8770
# Epoch [1080/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1090/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1100/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1110/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1120/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1130/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1140/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1150/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1160/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1170/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1180/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1190/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1200/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1210/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1220/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1230/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1240/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1250/10000] - Train Loss: 0.3506 | Train Acc: 0.8771
# Epoch [1260/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1270/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1280/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1290/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1300/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1310/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1320/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1330/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1340/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1350/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1360/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1370/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1380/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1390/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1400/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1410/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1420/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1430/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1440/10000] - Train Loss: 0.3506 | Train Acc: 0.8770
# Epoch [1450/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1460/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1470/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1480/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1490/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1500/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1510/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1520/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1530/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1540/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1550/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1560/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1570/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1580/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1590/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1600/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1610/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1620/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1630/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1640/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1650/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1660/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1670/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1680/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1690/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1700/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1710/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1720/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1730/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1740/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1750/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1760/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1770/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1780/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1790/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1800/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [1810/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1820/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1830/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1840/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1850/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1860/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1870/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1880/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1890/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1900/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1910/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1920/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1930/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1940/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1950/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1960/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1970/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1980/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [1990/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2000/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2010/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2020/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2030/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2040/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2050/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2060/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2070/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2080/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2090/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2100/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2110/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2120/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2130/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2140/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2150/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2160/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2170/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2180/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2190/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2200/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2210/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2220/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2230/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2240/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2250/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2260/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2270/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2280/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2290/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2300/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2310/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2320/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2330/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2340/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2350/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2360/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2370/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2380/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2390/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2400/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2410/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2420/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2430/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2440/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2450/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2460/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2470/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2480/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2490/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2500/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2510/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2520/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2530/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2540/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2550/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2560/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2570/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2580/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2590/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2600/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2610/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2620/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2630/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2640/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2650/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2660/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2670/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2680/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2690/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2700/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2710/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2720/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2730/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2740/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2750/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2760/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2770/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2780/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2790/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2800/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2810/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2820/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2830/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2840/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2850/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2860/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2870/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2880/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2890/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2900/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2910/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2920/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2930/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2940/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2950/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2960/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [2970/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2980/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [2990/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3000/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3010/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3020/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3030/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3040/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3050/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3060/10000] - Train Loss: 0.3505 | Train Acc: 0.8770
# Epoch [3070/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3080/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3090/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3100/10000] - Train Loss: 0.3505 | Train Acc: 0.8771
# Epoch [3110/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3120/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3130/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3140/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3150/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3160/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3170/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3180/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3190/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3200/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3210/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3220/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3230/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3240/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3250/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3260/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3270/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3280/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3290/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3300/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3310/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3320/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3330/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3340/10000] - Train Loss: 0.3504 | Train Acc: 0.8770
# Epoch [3350/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3360/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3370/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3380/10000] - Train Loss: 0.3504 | Train Acc: 0.8771
# Epoch [3390/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3400/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3410/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3420/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3430/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3440/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3450/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3460/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3470/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3480/10000] - Train Loss: 0.3504 | Train Acc: 0.8773
# Epoch [3490/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3500/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3510/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3520/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3530/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3540/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3550/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3560/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3570/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3580/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3590/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3600/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3610/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3620/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3630/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3640/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3650/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3660/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3670/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3680/10000] - Train Loss: 0.3504 | Train Acc: 0.8773
# Epoch [3690/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3700/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3710/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3720/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3730/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3740/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3750/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3760/10000] - Train Loss: 0.3504 | Train Acc: 0.8773
# Epoch [3770/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3780/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3790/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3800/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3810/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3820/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3830/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3840/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3850/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3860/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3870/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3880/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3890/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3900/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3910/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3920/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3930/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3940/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3950/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3960/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3970/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3980/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [3990/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4000/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4010/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4020/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4030/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4040/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4050/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4060/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4070/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4080/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4090/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4100/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4110/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4120/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4130/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4140/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4150/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4160/10000] - Train Loss: 0.3504 | Train Acc: 0.8773
# Epoch [4170/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4180/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4190/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4200/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4210/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4220/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4230/10000] - Train Loss: 0.3504 | Train Acc: 0.8773
# Epoch [4240/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4250/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4260/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4270/10000] - Train Loss: 0.3504 | Train Acc: 0.8772
# Epoch [4280/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4290/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4300/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4310/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4320/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4330/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4340/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4350/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4360/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4370/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4380/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4390/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4400/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4410/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4420/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4430/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4440/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4450/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4460/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4470/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4480/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4490/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4500/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4510/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4520/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4530/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4540/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4550/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4560/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4570/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4580/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4590/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4600/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4610/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4620/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4630/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4640/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4650/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4660/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4670/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4680/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4690/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4700/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4710/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4720/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4730/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4740/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4750/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4760/10000] - Train Loss: 0.3503 | Train Acc: 0.8771
# Epoch [4770/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4780/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4790/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4800/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4810/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4820/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4830/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4840/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4850/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [4860/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4870/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4880/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4890/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4900/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4910/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4920/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4930/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4940/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4950/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4960/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [4970/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [4980/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [4990/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5000/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5010/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5020/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5030/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5040/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5050/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5060/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5070/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5080/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5090/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5100/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5110/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5120/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5130/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5140/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5150/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5160/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5170/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5180/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5190/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5200/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5210/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5220/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5230/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5240/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5250/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5260/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5270/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5280/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5290/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5300/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5310/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5320/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5330/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5340/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5350/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [5360/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5370/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5380/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5390/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5400/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5410/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5420/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5430/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5440/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5450/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5460/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5470/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5480/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5490/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5500/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5510/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5520/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5530/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5540/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5550/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5560/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5570/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5580/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5590/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5600/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5610/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5620/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5630/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5640/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5650/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5660/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5670/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5680/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5690/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5700/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5710/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5720/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5730/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5740/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5750/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5760/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5770/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5780/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5790/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5800/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5810/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5820/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5830/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5840/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5850/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5860/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5870/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5880/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [5890/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5900/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5910/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5920/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5930/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5940/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5950/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5960/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5970/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [5980/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [5990/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6000/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6010/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6020/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6030/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6040/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6050/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6060/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6070/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6080/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6090/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6100/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6110/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6120/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6130/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6140/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6150/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6160/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6170/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6180/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6190/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6200/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6210/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6220/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6230/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6240/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6250/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6260/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6270/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6280/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6290/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6300/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6310/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6320/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6330/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6340/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6350/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [6360/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6370/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6380/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6390/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6400/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6410/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6420/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6430/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6440/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6450/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6460/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [6470/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6480/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6490/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6500/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6510/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6520/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6530/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6540/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6550/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6560/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6570/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6580/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6590/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6600/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6610/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6620/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6630/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6640/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6650/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6660/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6670/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6680/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6690/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6700/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6710/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6720/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6730/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [6740/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6750/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6760/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6770/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6780/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6790/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6800/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6810/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6820/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6830/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6840/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6850/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6860/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6870/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6880/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6890/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6900/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6910/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6920/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6930/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6940/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6950/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6960/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [6970/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6980/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [6990/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7000/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7010/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7020/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7030/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7040/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7050/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7060/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7070/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7080/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7090/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7100/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7110/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7120/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7130/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7140/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7150/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7160/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7170/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7180/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7190/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7200/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7210/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7220/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7230/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7240/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7250/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7260/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7270/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7280/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7290/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7300/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7310/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7320/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7330/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7340/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7350/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7360/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7370/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7380/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7390/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7400/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7410/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7420/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7430/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7440/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7450/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7460/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7470/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7480/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7490/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7500/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7510/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7520/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7530/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7540/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7550/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7560/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7570/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7580/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7590/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7600/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7610/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7620/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7630/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7640/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7650/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7660/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7670/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7680/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7690/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7700/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7710/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7720/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7730/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7740/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7750/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7760/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [7770/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7780/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7790/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7800/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7810/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7820/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7830/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7840/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7850/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7860/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7870/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7880/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7890/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7900/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7910/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7920/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7930/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7940/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7950/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7960/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7970/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [7980/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [7990/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8000/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8010/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8020/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [8030/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [8040/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8050/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8060/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8070/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [8080/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8090/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [8100/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8110/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8120/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8130/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8140/10000] - Train Loss: 0.3503 | Train Acc: 0.8772
# Epoch [8150/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8160/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [8170/10000] - Train Loss: 0.3503 | Train Acc: 0.8774
# Epoch [8180/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [8190/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [8200/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8210/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8220/10000] - Train Loss: 0.3503 | Train Acc: 0.8773
# Epoch [8230/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8240/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8250/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8260/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8270/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8280/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8290/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8300/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8310/10000] - Train Loss: 0.3502 | Train Acc: 0.8772
# Epoch [8320/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8330/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8340/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8350/10000] - Train Loss: 0.3502 | Train Acc: 0.8772
# Epoch [8360/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8370/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8380/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8390/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8400/10000] - Train Loss: 0.3502 | Train Acc: 0.8772
# Epoch [8410/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8420/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8430/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8440/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8450/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8460/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8470/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8480/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8490/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8500/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8510/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8520/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8530/10000] - Train Loss: 0.3502 | Train Acc: 0.8772
# Epoch [8540/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8550/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8560/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8570/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8580/10000] - Train Loss: 0.3502 | Train Acc: 0.8772
# Epoch [8590/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8600/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [8610/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8620/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8630/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8640/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8650/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8660/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8670/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [8680/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8690/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8700/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8710/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8720/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8730/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8740/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [8750/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8760/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8770/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8780/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8790/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8800/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8810/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8820/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8830/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8840/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8850/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8860/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8870/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8880/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8890/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8900/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8910/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8920/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8930/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8940/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8950/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8960/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8970/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [8980/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [8990/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9000/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9010/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9020/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9030/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9040/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9050/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9060/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9070/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9080/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9090/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9100/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9110/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9120/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9130/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9140/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9150/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9160/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9170/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9180/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9190/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9200/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9210/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9220/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9230/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9240/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9250/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9260/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9270/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9280/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9290/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9300/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9310/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9320/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9330/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9340/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9350/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9360/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9370/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9380/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9390/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9400/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9410/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9420/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9430/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9440/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9450/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9460/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9470/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9480/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9490/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9500/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9510/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9520/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9530/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9540/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9550/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9560/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9570/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9580/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9590/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9600/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9610/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9620/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9630/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9640/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9650/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9660/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9670/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9680/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9690/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9700/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9710/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9720/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9730/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9740/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9750/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9760/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9770/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9780/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9790/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9800/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9810/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9820/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9830/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9840/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9850/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9860/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9870/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9880/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9890/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9900/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9910/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9920/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9930/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9940/10000] - Train Loss: 0.3502 | Train Acc: 0.8773
# Epoch [9950/10000] - Train Loss: 0.3502 | Train Acc: 0.8775
# Epoch [9960/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9970/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9980/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [9990/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
# Epoch [10000/10000] - Train Loss: 0.3502 | Train Acc: 0.8774
#
# --- Test Set Evaluation ---
# AUC:       0.6730
# Log Loss:     0.3542
# Brier Score:  0.1034
# Accuracy:  0.8735
# Precision: 0.4962
# F1 Score:  0.0533

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(7,5))
fpr, tpr, thresholds = roc_curve(y_test_tensor.numpy(), test_probs)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal reference line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - final xnn model')
plt.legend(loc="lower right")
plt.show()

# %%
torch.save(model_1, 'simplernet_full_model.pth')

# %%
X.shape
# Out:
# (74087, 4)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_tensor = torch.tensor(X_scaled, dtype=torch.float32)


model_1.eval()
with torch.no_grad():
    test_all_logits = model_1(X_tensor)
    test_all_probs = torch.sigmoid(test_all_logits).numpy()
    test_all_preds = (test_all_probs >= 0.5).astype(int)

# %%
test_all_probs
# Out:
# array([[0.06891645],
#        [0.09782922],
#        [0.05340003],
#        ...,
#        [0.04912348],
#        [0.23387554],
#        [0.05786038]], dtype=float32)

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
df_features['xT'] = test_all_probs

# %%
features_2022_2023_final = pd.read_csv("data/features_2022_2023_final.csv")

# %%
features_2022_2023_final.to_csv("features_2022_2023_final.csv",index=False)

# %% [markdown]
# ### features contribution

# %%
xnn_contribution = df_features[['pressure based', 'speed based', 'position based',
       'event based']]

# %% [markdown]
# ### contribution of model

# %%
gamma_weights = model_1.model[0].weight.detach().numpy()        # (16, 4)
final_weights = model_1.model[2].weight.detach().numpy().flatten()  # (16,)
# Effective γ values from each h_k to output
effective_gamma = final_weights @ gamma_weights  # (4,)
# Add contributions to DataFrame
for i, h_col in enumerate(['pressure based', 'speed based', 'position based','event based']):
    xnn_contribution[f"{h_col}_contrib"] = xnn_contribution[f"{h_col}"] * effective_gamma[i]
    xnn_contribution[f"{h_col}_contrib"] -= xnn_contribution[f"{h_col}_contrib"].mean()
xnn_df = xnn_contribution[['pressure based_contrib','speed based_contrib',
       'position based_contrib','event based_contrib']]
xnn_df.insert(0, 'id', features_all['id'].values)
# Out:
# /tmp/ipykernel_554942/1709569493.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xnn_contribution[f"{h_col}_contrib"] = xnn_contribution[f"{h_col}"] * effective_gamma[i]
# /tmp/ipykernel_554942/1709569493.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xnn_contribution[f"{h_col}_contrib"] -= xnn_contribution[f"{h_col}_contrib"].mean()
# /tmp/ipykernel_554942/1709569493.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xnn_contribution[f"{h_col}_contrib"] = xnn_contribution[f"{h_col}"] * effective_gamma[i]
# /tmp/ipykernel_554942/1709569493.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xnn_contribution[f"{h_col}_contrib"] -= xnn_contribution[f"{h_col}_contrib"].mean()
# /tmp/ipykernel_554942/1709569493.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xnn_contribution[f"{h_col}_contrib"] = xnn_contribution[f"{h_col}"] * effective_gamma[i]
# /tmp/ipykernel_554942/1709569493.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xnn_contribution[f"{h_col}_contrib"] -= xnn_contribution[f"{h_col}_contrib"].mean()
# /tmp/ipykernel_554942/1709569493.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xnn_contribution[f"{h_col}_contrib"] = xnn_contribution[f"{h_col}"] * effective_gamma[i]
# /tmp/ipykernel_554942/1709569493.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xnn_contribution[f"{h_col}_contrib"] -= xnn_contribution[f"{h_col}_contrib"].mean()

# %%
xnn_df
# Out:
#                id  pressure based_contrib  speed based_contrib  \
# 0      1256506933               -0.010855             0.024089
# 1      1256508233               -0.002199            -0.000200
# 2      1256507062               -0.004298             0.040641
# 3      1256507101               -0.006372            -0.016311
# 4      1256507134                0.000127            -0.041847
# ...           ...                     ...                  ...
# 74082  1625749288                0.010077             0.029131
# 74083  1625749300               -0.003197             0.041944
# 74084  1625749310               -0.000096            -0.091719
# 74085  1625748978                0.005076            -0.006083
# 74086  1625748995               -0.010855             0.021695
#
#        position based_contrib  event based_contrib
# 0                   -0.000987            -0.021099
# 1                   -0.000564            -0.009828
# 2                   -0.002026            -0.019119
# 3                    0.000371             0.005406
# 4                   -0.001789            -0.022335
# ...                       ...                  ...
# 74082                0.001231             0.056361
# 74083                0.003699            -0.019501
# 74084                0.009146             0.009547
# 74085                0.002204             0.032180
# 74086               -0.001543            -0.023082
#
# [74087 rows x 5 columns]

# %% [markdown]
# ### contribution of features

# %%
import pandas as pd
from collections import defaultdict

# 1) Your four DataFrames of (feature, coefficient)
logistic_df = [df_params_model_1, df_params_model_2, df_params_model_3, df_params_model_4]

df_features_contrib = df_features[['packing', 'pressure_on_passer', 'teammates_nearby', 'opponents_nearby',
       'average_speed_of_teammates', 'average_speed_of_opponents',
       'teammates_behind', 'teammates_beyond', 'opponents_beyond',
       'opponents_behind', 'opponents_between', 'start_distance_to_goal',
       'end_distance_to_goal', 'pass_length', 'pass_angle',
       'start_angle_to_goal', 'end_angle_to_goal',
       'start_distance_to_sideline', 'end_distance_to_sideline']]

# 2) Head names (you only need to define this once)
h_names = [
    "pressure based",
    "speed based",
    "position based",
    "event based",
]

# 3) Build a dict of dicts: { head_name: { feature: beta, … }, … }
logistic_coeffs = {
    h: dict(zip(df.iloc[:, 0], df.iloc[:, 1]))
    for h, df in zip(h_names, logistic_df)
}

# 4) Grab your gamma weights just once (shape should be (4,))
gamma_weights = model_1.model[0].weight.detach().numpy()        # (16, 4)
final_weights = model_1.model[2].weight.detach().numpy().flatten()
effective_gamma = final_weights @ gamma_weights 

# 6) Fill it in
for i, h in enumerate(h_names):
    beta_dict = logistic_coeffs[h]
    γ = effective_gamma[i]
    for feature, β in beta_dict.items():
        if feature in df_features_contrib.columns:
            df_features_contrib[feature] = df_features_contrib[feature] * β * γ
            df_features_contrib[feature] -= df_features_contrib[feature].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 40
#      38 for feature, β in beta_dict.items():
#      39     if feature in df_features_contrib.columns:
# ---> 40         df_features_contrib[feature] = df_features_contrib[feature] * β * effective_gamma
#      41         df_features_contrib[feature] -= df_features_contrib[feature].mean()
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/pandas/core/arraylike.py:202, in OpsMixin.__mul__(self, other)
#     200 @unpack_zerodim_and_defer("__mul__")
#     201 def __mul__(self, other):
# --> 202     return self._arith_method(other, operator.mul)
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/pandas/core/series.py:6115, in Series._arith_method(self, other, op)
#    6113 def _arith_method(self, other, op):
#    6114     self, other = self._align_for_op(other)
# -> 6115     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/pandas/core/base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     215     func = partial(expressions.evaluate, op)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     239 if op_str is not None:
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/anaconda3/envs/thesis/lib/python3.9/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      71 if _TEST_MODE:
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# ValueError: operands could not be broadcast together with shapes (74087,) (4,)

# %%
contribution_features = df_features_contrib
contribution_features['id'] = features_all['id']
# Out:
# /tmp/ipykernel_554942/355674837.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contribution_features['id'] = features_all['id']

# %% [markdown]
# ## contribution plot of models in xNN(took mean of feature values)

# %%
import matplotlib.pyplot as plt
import pandas as pd

xnn_plot = xnn_contribution[['pressure based_contrib','speed based_contrib',
       'position based_contrib','event based_contrib']]

means_plot = xnn_plot.mean().fillna(0)
df_mean_plot = means_plot.to_frame(name="Mean Contribution")

fig, ax = plt.subplots(figsize=(8,6))
bars = ax.barh(
    df_mean_plot.index,
    df_mean_plot["Mean Contribution"],
    color="steelblue",    # ← same color for every bar
    edgecolor="black"
)

ax.axvline(0, color="black", linestyle="--", alpha=0.7)
ax.set_title("Feature contribution plot of per feature from xNN")
ax.set_xlabel("contribution values with positive and negative correlation")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### contribution plot of xNN per feature

# %%
### have taken mean of features again just to plot
import matplotlib.pyplot as plt
import pandas as pd

df_plot = df_features_contrib.drop(['id'],axis=1)
means = df_plot.mean().fillna(0)
df_mean = means.to_frame(name="Mean Contribution")

fig, ax = plt.subplots(figsize=(8,6))
bars = ax.barh(
    df_mean.index,
    df_mean["Mean Contribution"],
    color="steelblue",    # ← same color for every bar
    edgecolor="black"
)

ax.axvline(0, color="black", linestyle="--", alpha=0.7)
ax.set_title("Feature contribution plot of per feature from xNN")
ax.set_xlabel("contribution values with positive and negative correlation")

plt.tight_layout()
plt.show()

# %%
df_params_model_1.to_csv("pressure_model_params.csv",index=False)

# %%
df_params_model_2.to_csv("speed_model_params.csv",index=False)

# %%
df_params_model_3.to_csv("position_model_params.csv",index=False)

# %%
df_params_model_4.to_csv("event_model_params.csv",index=False)

# %% [markdown]
# ### plot of model contribution and per feature contribution for single pass

# %%
import matplotlib.pyplot as plt
import pandas as pd

row = (
    xnn_df[xnn_df["id"] == 1442323882]
    .iloc[0]        
    .drop("id")
)
df_mean = row.to_frame(name="Mean Contribution")

fig, ax = plt.subplots(figsize=(8,6))
bars = ax.barh(
    df_mean.index,
    df_mean["Mean Contribution"],
    color="steelblue",    # ← same color for every bar
    edgecolor="black"
)

ax.axvline(0, color="black", linestyle="--", alpha=0.7)
ax.set_title("Feature contribution plot from logistic regression")
ax.set_xlabel("contribution values with positive and negative correlation")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

row = (contribution_features[contribution_features["id"] == 1442323882]
    .iloc[0]                  
    .drop("id")
)
df_mean = row.to_frame(name="Mean Contribution")

fig, ax = plt.subplots(figsize=(8,6))
bars = ax.barh(
    df_mean.index,
    df_mean["Mean Contribution"],
    color="steelblue",    # ← same color for every bar
    edgecolor="black"
)

ax.axvline(0, color="black", linestyle="--", alpha=0.7)
ax.set_title("Feature contribution plot from logistic regression")
ax.set_xlabel("contribution values with positive and negative correlation")

plt.tight_layout()
plt.show()
